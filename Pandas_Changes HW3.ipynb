# %% [markdown]
# ## Задача 1
#
# ### Задание 1.1
# Скачать данные по ссылке https://www.kaggle.com/datasets/ionaskel/laptop-prices
#
# Считать данные с помощью pandas
#
# Вывести на экран первые 5 строк

# %%
import pandas as pd

# %%
df = pd.read_csv('./kc-house-data.csv', encoding = "1251")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# ###  Задание 1.2
# Создать новый признак delta_renovated, который будет содержать разницу в годах между годом реновацией дома и годом постройки дома
#
# Если реновации дома не было, то в новом признаке поставьте 0

# %%
def renovation():
    delta_renovated = []
    for i, row in df.iterrows():
        if row['yr_renovated'] > 0:
            delta_renovated.append(row['yr_renovated'] - row['yr_built'])
        else:
            delta_renovated.append(0)
    return delta_renovated

df['delta_renovated'] = renovation()
df.sample(10)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21503  9268851020  20150410T000000  735000.0         4       3.50
# 1834   9315300260  20140521T000000  189650.0         2       1.75
# 16495   205000050  20141218T000000  735000.0         4       2.50
# 14414  1545807920  20141015T000000  245000.0         3       1.75
# 2567   6071700160  20140623T000000  603500.0         6       2.75
# 21228  7853320950  20141023T000000  412500.0         3       2.00
# 8365   7340600845  20140806T000000  185000.0         4       1.00
# 10386  6620400400  20140813T000000  309950.0         1       1.00
# 2352   7229700105  20150424T000000  172500.0         2       2.00
# 6404   4399210130  20140626T000000  225500.0         2       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 21503         2340      2810     2.0           0     2  ...        1730
# 1834          1100      7600     1.0           0     0  ...        1100
# 16495         3270     45537     2.0           0     0  ...        3270
# 14414         1260      8614     1.0           0     0  ...        1260
# 2567          2660      8400     1.0           0     0  ...        1550
# 21228         1680      5246     1.0           0     0  ...        1680
# 8365          1380      6700     1.0           0     0  ...        1190
# 10386         1120     11800     1.5           0     0  ...        1120
# 2352          1510     20685     1.0           0     0  ...        1250
# 6404          1590     11276     1.0           0     0  ...        1590
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 21503            610      2011             0    98027  47.5403 -122.028
# 1834               0      1980             0    98198  47.4136 -122.318
# 16495              0      1993             0    98053  47.6303 -121.984
# 14414              0      1985             0    98038  47.3586 -122.056
# 2567            1110      1962             0    98006  47.5490 -122.173
# 21228              0      2007             0    98065  47.5206 -121.868
# 8365             190      1928             0    98168  47.4871 -122.281
# 10386              0      1950             0    98168  47.5123 -122.331
# 2352             260      1958             0    98059  47.4810 -122.116
# 6404               0      1972             0    98002  47.3177 -122.210
#
#        sqft_living15  sqft_lot15  delta_renovated
# 21503           2600        2843                0
# 1834            1230        7350                0
# 16495           2670       38827                0
# 14414           1600        8614                0
# 2567            2280        8400                0
# 21228           2430        6883                0
# 8365            1380        8292                0
# 10386           2330        9290                0
# 2352            1490       29527                0
# 6404            1750       10687                0
#
# [10 rows x 22 columns]

# %% [markdown]
# ### Задание 1.3
# Создайте признаки года продажи, месяца продажи

# %%
df['year_sale'] = pd.DatetimeIndex(df['date']).year
df['month_sale'] = pd.DatetimeIndex(df['date']).month
df[['date', 'year_sale', 'month_sale']].head()
# Out:
#               date  year_sale  month_sale
# 0  20141013T000000       2014          10
# 1  20141209T000000       2014          12
# 2  20150225T000000       2015           2
# 3  20141209T000000       2014          12
# 4  20150218T000000       2015           2

# %% [markdown]
# ### Задание 1.4
# Удалите признаки date, zipcode, lat, long

# %%
df.drop(columns = ['date', 'zipcode', 'lat', 'long'], inplace = True)
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  sqft_living15  sqft_lot15  delta_renovated  year_sale  \
# 0             0           1340        5650                0       2014
# 1          1991           1690        7639               40       2014
# 2             0           2720        8062                0       2015
# 3             0           1360        5000                0       2014
# 4             0           1800        7503                0       2015
#
#    month_sale
# 0          10
# 1          12
# 2           2
# 3          12
# 4           2

# %% [markdown]
# ## Задача 2
# Создайте датафрейм с клиентами:
#
# clients = pd.DataFrame({
#
# 'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295,
# 939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242,
# 2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474],
#
# 'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060,
# 1189000207, 6821600300, 7137950720, 9510920050, 6131600255,
# 5428000070, 1788800910, 8100400160, 3123049142, 6306800010,
# 5083000375, 7920100025, 1951600150, 809001400, 339600110,
# 1622049154, 1099600250, 8563000110, 2768100205, 3995700435,
# 8861700030, 3303980210, 7731100066, 8146100580, 825069097,
# 3889100029, 9524100196]
#
# })

# %% [markdown]
# ### Задание 2.1
# Присоедините к таблице clients данные по домам через метод join

# %%
clients = pd.DataFrame({

'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295,
              939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242,
              2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474],

'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060,
             1189000207, 6821600300, 7137950720, 9510920050, 6131600255,
             5428000070, 1788800910, 8100400160, 3123049142, 6306800010,
             5083000375, 7920100025, 1951600150, 809001400, 339600110, 
             1622049154, 1099600250, 8563000110, 2768100205, 3995700435,
             8861700030, 3303980210, 7731100066, 8146100580, 825069097, 
             3889100029, 9524100196]

})

# %%
clients = clients.set_index('house_id')
df = df.set_index('id')
clients.join(df).reset_index().head()
# Out:
#         index  client_id     price  bedrooms  bathrooms  sqft_living  \
# 0   339600110       4809  395000.0         3       2.50         1610
# 1   809001400       3113  925000.0         3       1.00         1630
# 2   825069097       1764  770000.0         3       2.50         2650
# 3  1099600250       2242  260000.0         3       1.75         1710
# 4  1189000207       2308  387000.0         2       2.50         1170
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      3755     2.0           0     0  ...      7        1610              0
# 1      3200     1.5           0     0  ...      8        1630              0
# 2     40705     2.0           0     0  ...      9        2650              0
# 3      6400     1.0           0     0  ...      7        1240            470
# 4      1394     2.0           0     0  ...      8        1170              0
#
#    yr_built  yr_renovated  sqft_living15  sqft_lot15  delta_renovated  \
# 0      1987             0           1300        3823                0
# 1      1912             0           1710        3600                0
# 2      1994             0           2550       42625                0
# 3      1976             0           1600        6400                0
# 4      2001             0           1250        3136                0
#
#    year_sale  month_sale
# 0       2014           9
# 1       2014           9
# 2       2014           6
# 3       2014          12
# 4       2014          10
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Задание 2.2
# Присоедините к таблице clients данные по домам через метод merge
#
# Это нужно, чтобы понимать, какие дома покупались клиентами
#
# house_id - это индексы датафрейма с домами

# %%
merged = clients.merge(df, left_on = 'house_id', right_on = 'id', how = 'left')
merged.head()
# Out:
#    client_id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0       1459  295000.0         3       2.50         1500      3060     2.0
# 1       4684  700000.0         4       1.75         1870      6000     1.0
# 2       3498  679000.0         4       2.50         3680      7236     2.0
# 3       3942  420000.0         3       1.75         1720      5000     1.5
# 4       4535  518000.0         4       2.75         2520     14021     2.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1500              0      1994
# 1           0     0          5      8        1670            200      1949
# 2           0     0          3     10        3680              0      2006
# 3           0     0          3      8        1720              0      1932
# 4           0     0          3      9        2520              0      1999
#
#    yr_renovated  sqft_living15  sqft_lot15  delta_renovated  year_sale  \
# 0             0           2700        7734                0       2015
# 1             0           1710        6000                0       2015
# 2             0           3310        7180                0       2015
# 3          2009           1410        8300               77       2014
# 4             0           2330       14007                0       2014
#
#    month_sale
# 0           2
# 1           4
# 2           5
# 3          12
# 4           6

# %% [markdown]
# ## Задача 3
# Составьте несколько сводных таблиц

# %% [markdown]
# ### Задание 3.1
# Найдите среднюю стоимость домов в зависимости от количества спален
#
# Отсортируйте от меньшей стоимости к большей

# %%
df.groupby('bedrooms').agg({'price': 'mean'}).sort_values('price')
# Out:
#                  price
# bedrooms
# 1         3.176429e+05
# 2         4.013727e+05
# 0         4.095038e+05
# 3         4.662321e+05
# 11        5.200000e+05
# 4         6.354195e+05
# 33        6.400000e+05
# 5         7.865998e+05
# 10        8.193333e+05
# 6         8.255206e+05
# 9         8.939998e+05
# 7         9.511847e+05
# 8         1.105077e+06

# %% [markdown]
# ### Задание 3.2
# Найдите минимальную, среднюю и максимальную стоимости домов в зависимости от состояния дома

# %%
df.groupby('condition').agg({'price': ['min', 'mean', 'max']})
# Out:
#               price
#                 min           mean        max
# condition
# 1           78000.0  334431.666667  1500000.0
# 2           80000.0  327287.145349  2555000.0
# 3           75000.0  542012.578148  7062500.0
# 4           89000.0  521200.390033  7700000.0
# 5          110000.0  612418.089359  3650000.0

# %% [markdown]
# ### Задание 3.3
# Постройте таблицу с подсчетом количества домов в данных в зависимости от вида на набережную и оценкой вида

# %%
df.pivot_table(index = 'waterfront', columns = 'view', values = 'bedrooms', aggfunc = 'count', fill_value = 0)
# Out:
# view            0    1    2    3    4
# waterfront
# 0           19489  331  955  491  184
# 1               0    1    8   19  135

# %% [markdown]
# ### Задание 3.4
# Каких домов в зависимости от этажности и количества спален больше?

# %%
df.pivot_table(index = 'bedrooms', columns = 'floors', values = 'view', aggfunc = 'count', fill_value = 0)
# Out:
# floors     1.0  1.5   2.0  2.5  3.0  3.5
# bedrooms
# 0            4    0     6    0    2    1
# 1          162   21    12    1    3    0
# 2         1951  182   497    5  123    2
# 3         5455  786  3118   56  405    4
# 4         2383  698  3682   58   61    0
# 5          605  185   775   23   13    0
# 6          104   30   119   14    5    0
# 7            9    7    19    2    1    0
# 8            5    1     6    0    0    1
# 9            0    0     4    2    0    0
# 10           1    0     2    0    0    0
# 11           0    0     1    0    0    0
# 33           1    0     0    0    0    0

# %% [markdown]
# ### Задание 3.5
# Постройте таблицу с подсчетом медианной стоимости домов в данных в зависимости от состояния дома и оценки дома

# %%
df.pivot_table(index = 'condition', columns = 'grade', values = 'price', aggfunc = 'median', fill_value = 0)
# Out:
# grade          1       3       4       5       6       7       8        9   \
# condition
# 1          142000       0  150000  190000  255000  403500  932500        0
# 2               0  280000  145000  180000  235000  305000  429000   715000
# 3               0   75000  205000  234475  265000  357500  485000   689000
# 4               0       0  238525  229975  295000  390000  571250   823500
# 5               0  262000       0  227450  285475  456000  696000  1078000
#
# grade           10       11       12       13
# condition
# 1                0        0        0        0
# 2          1752500        0        0        0
# 3           890000  1209500  1807500  2888000
# 4          1030000  1685000  2125000  5750000
# 5          1650000  2050000  1990000        0
